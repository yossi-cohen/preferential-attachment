# %% [markdown]
# # universal estimator-exp-1a (uniform sampling)
#
# Let $f(d)$ be a one dimensional function, that returns a samples drawn from a univariate distribution (e.g., log-normal).
#
# **Research question**: Let $e = (\vec{pred\_params} - \vec{test\_params})$.
# Does $STD(e)$ decreases when the parameter-search-space gets smaller?
#
# 1. Generate a sample (256 observations) using $f$ e.g: $sample = f(d=0.92, size=256)$
# 2. $estimator(f, sample)$ is a function which learns the parameter $d$ of $f$ from the sample.
#
# > - Init: search_space = [0, 1]
# >
# > - Iterate:
# >   1. Generate synthetic data-set ( train / test ) using $f(d)$ with two settings (exp-1a, exp-1b):
# >          d ~ uniform(search_space)
# >          d ~ norm(search_space)
# >   2. Fit a DNN model to the training set
# >          e = (pred_params - test_params)
# >          sigma = STD(e)
# >   3. Predict the parameter $d\_pred$ on the input sample using the DNN model
# >          d_pred = model.predict(sample)
# >   4. Narrow the search space:
# >          pivot = d_pred
# >          scale = 3 * std(e)
# >          search_space = [ pivot - scale, pivot + scale ]
# >          if next_search_space == search_space: narrow the search_space by epsilon = 0.003
# >          (here I'm interested merely on narrowing the search_space, not on "correct" focusing)
# >   5. Stop when either one of the following:
# >      - search-space-width < 1/128 * initial-search-space-width [0, 1]
# >      - std(e) <= 0.005
#
# > - Return:
# >   - d_pred_array: array of d_pred predicted at each iteration (3)
# >   - search_spaces: array of search-space at each iteration (4)
# >   - (pred-set, test-set) at each iteration
#
# 3. Plot a graph:
#
# >   - $x$: iteration #
# >   - $y1$: sigma_1 = STD(pred_params - test_params)
# >   - $y2$: abs(d_pred - d_true)
# >
# > Plot (shaded) intervals around sigma_1:
# >
# > - sigma_2:
# >          mu = mean(e)
# >          var_2 = 1/n * sum( ( (e - mu) ^ 2 - (sigma_1) ^ 2 ) ^ 2 )
# >          sigma_2 = sqrt(var_2)
# >
# > - 3 * sigma_1
#
# **Results**:
#
# The experiment was run on a true parameter: $d\_true =$ 0.92
# As can be shown by the plot:
# > 1. The error (sigma_1) keeps decreasing as we narrow the search-space.
# > 2. abs(d_pred - d_true) stabelizes (less flactuations) as we narrow the search-space.
# > 3. The model predictions (pred_params) in the last iteration are within the (narrowest) search space.
#
# ![image-4.png](attachment:image-4.png)

# %%
# import library
# %run lib.ipynb
np.set_printoptions(precision=4)

# %%
from scipy import stats
from scipy.stats import lognorm
from scipy.stats import yulesimon

# sample from lognormal
def sample_lognormal(config, size):
    return lognorm.rvs(s=config, size=size, random_state=RANDOM_STATE)

# sample from yulesimon
def sample_yulesimon(config, size):
    return yulesimon.rvs(alpha=config, size=size, random_state=RANDOM_STATE)

def next_config(search_space, loc=-1, scale=-1):

    """
    return a (uniform/normal) random parameter within search_space
    """
    low = search_space[0]
    high = search_space[1]
    if loc < 0:
        return np.random.uniform(low, high, size=1)[0]
    
    param = np.random.normal(loc=loc, scale=scale, size=1)[0]

    # adjust from left
    param_adjusted = max(search_space[0], param)
    param_adjusted = max(0.01, param)
    
    # adjust from right
    param_adjusted = min(param_adjusted, search_space[1])
    
    return param_adjusted

# %%
# def MAE(e, axis=-1):
#     """mean absolute error"""
#     return np.mean(np.abs(e), axis=axis)

NUM_BINS = 346

def predict_d(f, sample, d_true, search_space, num_trials=1, N=1000, search_pivot=-1, search_scale=-1):
    
    """
    Learn parameters of f, from sample.
    Arguments:
        - f: one dimensional function that gives the PMF of a univariate distribution.
        - sample: generated using f.
    """

    # number of observations in sample
    M = len(sample)
    N = N

    nbins = NUM_BINS
    
    # Generate a histogram for the input *sample*
    H_sample = np.histogram(sample, bins=nbins, range=(0,nbins), density=False)[0]
    H_sample = np.reshape(H_sample, (1, -1))
    
    # Iterate   
    d_pred_array = np.zeros(num_trials)
    for trial_idx in range(num_trials):

        # 1. Generate synthetic data-sets (train/test) using f (within search_space)
        # -----------------------------------------------------------------------------------------------
        print()
        print(f'search_space: {search_space} - trial ({trial_idx+1}/{num_trials})')
        print(f'generating data (M={M}, N={N})', end=', ')

        raw, H, params = generate_data(N=N, 
                                       M=M, 
                                       sample=f, 
                                       nextConfig=lambda: next_config(
                                           search_space, 
                                           loc=search_pivot, 
                                           scale=search_scale),
                                       nbins=nbins,
                                       density=False, 
                                       apply_log_scale=False)

        H_train, H_test, train_params, test_params = train_test_split(H, 
                                                                      params, 
                                                                      test_size=0.25, 
                                                                      random_state=RANDOM_STATE)

        # 2. Fit a DNN model to train-set and predict on test-set
        # -----------------------------------------------------------------------------------------------

        # train
        print(f'training ...', end=' ')
        dnn_model, history = dnn_fit(X_train=H_train, y_train=train_params)

        # predict test
        pred_params = dnn_model.predict(H_test).flatten()

        # error
        e = pred_params - test_params

        # 3. Predict the parameter (d_pred) on the input sample
        # -----------------------------------------------------------------------------------------------

        d_pred = dnn_model.predict(H_sample).flatten()[0]
        d_pred_array[trial_idx] = d_pred
        
        print(f'STD(test): {np.std(e):.4f}', end=', ')
        print(f'd_pred: {d_pred:.4f}', end='')
        if len(d_pred_array) > 1:
            print(f', avg(d_pred): {np.mean(d_pred_array[:trial_idx+1]):.4f}')
        else:
            print()

    return d_pred_array, test_params, pred_params

# %%
def estimator_exp_1(f, sample, d_true, initial_search_space):

    # experiment results
    res = {
        'search_space': [],
        'test_params': [],
        'pred_params': [],
        'd_true': d_true,
        'd_pred': [],
    }

    initial_search_space_width = initial_search_space[1] - initial_search_space[0]
    search_space = initial_search_space
    
    # Iterate
    it = 0
    search_pivot = -1
    search_scale = -1
    
    while True:
        
        it += 1
        
        num_trials = 1
        
        d_pred_array, test_params, pred_params = predict_d(f, 
                                                           sample, 
                                                           d_true, 
                                                           search_space, 
                                                           num_trials=num_trials, 
                                                           N=1000, 
#                                                            search_pivot=search_pivot, 
#                                                            search_scale=search_scale)
                                                           search_pivot=-1, 
                                                           search_scale=-1)
        
        d_pred = np.mean(d_pred_array)

        print()
        if len(d_pred_array) > 1:
            print(f'*** avg(d_pred): {d_pred:.4f}', end=', ')
        else:
            print(f'*** d_pred: {d_pred:.4f}', end=', ')
        print(f'abs_error: {abs(d_pred - d_true):.4f}')
        
        # save results
        res['search_space'].append(search_space)
        res['test_params'].append(test_params)
        res['pred_params'].append(pred_params)
        res['d_pred'].append(d_pred)
        
        # update the search_space
        # ------------------------

        search_pivot = d_pred
        search_STD = np.std(pred_params - test_params)

#         std_factor = 1
#         std_factor = 2
        std_factor = 3

        search_scale = std_factor * search_STD
        print(f'search_pivot: {search_pivot:.4f}, search_scale ({std_factor}*STD) = {search_scale:.4f}')
        
        next_search_space = np.array([ 
            max(search_space[0], search_pivot - search_scale), 
            min(search_space[1], search_pivot + search_scale)])
        
        # if no change in search_space, narrow by epsilon
        if np.array_equal(search_space, next_search_space):
            epsilon = 0.003
            print(f'no change in search_space. narrowing by epsilon: {epsilon:.4f}')
            search_space = np.array([search_space[0] + epsilon, search_space[1] - epsilon])
        else:
            search_space = next_search_space
        
        # stop condition: size of the search-space (high-low) is 1/128 of the original
        search_space_width = search_space[1] - search_space[0]
        search_space_shrink_factor = 1/128
        if search_space_width < search_space_shrink_factor * initial_search_space_width:
            epsilon = 0 # stop epsilon narrowing
#             break

        # stop condition (2): search_STD <=0.01
        if search_STD <= 0.001:
            break

    res['search_space'] = np.array(res['search_space'])
    res['test_params'] = np.array(res['test_params'])
    res['pred_params'] = np.array(res['pred_params'])
    res['d_pred'] = np.array(res['d_pred'])
    
    return res

# %% [markdown]
# ## Plot

# %%
def plot_search_space_size_vs_d_pred_error(res):

    search_space = res['search_space']
    search_space_width = search_space[:,1] - search_space[:,0]
    search_space_final = search_space[-1]
    
    d_true = res['d_true']
    d_pred = res['d_pred']
    d_pred_final = d_pred[-1] # d_pred of the last (narrowest) search_space
    d_pred_abs_error = np.abs(d_pred - d_true)

    pred_params = res['pred_params']
    test_params = res['test_params']

    # errors in each iteration
    e = pred_params - test_params
    
    # num-iterations
    n = e.shape[0]
    
    # avg error of each iteration
    mu = np.mean(e, axis=1).reshape((n,-1))
    
    # STD in each iteration
    sigma_1 = np.std(e, axis=1)

    # sigma_2
    mu = np.mean(e, axis=1).reshape(n, 1)
    var_2 = 1/n * np.sum(np.square(np.square(e - mu) - np.square(sigma_1).reshape(n,1)), axis=1)
    sigma_2 = np.sqrt(var_2)

    # iteration number
    x = np.array(range(n))
    
    # PLOT
    title = f'search space vs. prediction error \n\
    search_space_final: {search_space_final} \n\
    e = (pred_params - test_params) \n\
    d_true: {d_true}, d_pred_final: {d_pred_final:.4f}'
    
    fig, axes  = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
    
    for ax in axes:

        # zero reference line
        ax.plot(x, np.zeros(n), zorder=2, c='black', linewidth=0.5)

        ax.set_xlabel('iteration')
        
        if ax == axes[0]:
            ax.set_title(title)
            y1 = sigma_1
            y2 = d_pred_abs_error
            ax.set_ylabel('error')
        else:
            ax.set_title('log-scale')
            y1 = np.log10(y1)
            y2 = np.log10(y2)
            ax.set_ylabel('log10(error)')

        ax.scatter(x, y1, zorder=1, s=2, c='blue', label='sigma_1')
        ax.plot(x, y1, zorder=2, c='blue', alpha=0.2)
        
        # confidence_interval_1: sigma_1 +- 3*sigma_1
        ax.fill_between(range(len(x)), 
                         y1 - 3*sigma_1, y1 + 3*sigma_1, 
                         facecolor='green', alpha=0.2, label='3*sigma_1')

        # confidence_interval_2: sigma_1 +- sigma_2
        ax.fill_between(range(len(x)), 
                         y1 - sigma_2, y1 + sigma_2, 
                         facecolor='red', alpha=0.4, label='sigma_2')

        # y2 (d_pred)
        ax.scatter(x, y2, zorder=1, s=2, c='green', label='abs(d_pred - d_true)')
        ax.plot(x, y2, zorder=2, c='green', alpha=0.3)
    
        if ax == axes[0]:
            ax.legend(loc='upper right')
            
    plt.show()

# %% [markdown]
# ## Fit (lognormal)

# %%
for d_true in [0.92]:
    print()
    print(f'param true value: {d_true}')
    f = sample_lognormal
    sample = f(config=d_true, size=256)
    initial_search_space=np.array([0.0, 1.0])
    res = estimator_exp_1(f=f, sample=sample, d_true=d_true, initial_search_space=initial_search_space)
    plot_search_space_size_vs_d_pred_error(res)
# Out:
# param true value: 0.92
#
# search_space: [0. 1.] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0633, d_pred: 0.8582
#
# *** d_pred: 0.8582, abs_error: 0.0618
# search_pivot: 0.8582, search_scale (3*STD) = 0.1900
#
# search_space: [0.6682 1.    ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0551, d_pred: 0.9512
#
# *** d_pred: 0.9512, abs_error: 0.0312
# search_pivot: 0.9512, search_scale (3*STD) = 0.1652
#
# search_space: [0.7859 1.    ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0489, d_pred: 0.8667
#
# *** d_pred: 0.8667, abs_error: 0.0533
# search_pivot: 0.8667, search_scale (3*STD) = 0.1466
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7889 0.997 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0515, d_pred: 0.8635
#
# *** d_pred: 0.8635, abs_error: 0.0565
# search_pivot: 0.8635, search_scale (3*STD) = 0.1544
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7919 0.994 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0508, d_pred: 0.8901
#
# *** d_pred: 0.8901, abs_error: 0.0299
# search_pivot: 0.8901, search_scale (3*STD) = 0.1523
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7949 0.991 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0504, d_pred: 0.9494
#
# *** d_pred: 0.9494, abs_error: 0.0294
# search_pivot: 0.9494, search_scale (3*STD) = 0.1512
#
# search_space: [0.7982 0.991 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0525, d_pred: 0.9707
#
# *** d_pred: 0.9707, abs_error: 0.0507
# search_pivot: 0.9707, search_scale (3*STD) = 0.1575
#
# search_space: [0.8132 0.991 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0475, d_pred: 0.9244
#
# *** d_pred: 0.9244, abs_error: 0.0044
# search_pivot: 0.9244, search_scale (3*STD) = 0.1424
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8162 0.988 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0434, d_pred: 0.9294
#
# *** d_pred: 0.9294, abs_error: 0.0094
# search_pivot: 0.9294, search_scale (3*STD) = 0.1302
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8192 0.985 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0435, d_pred: 0.8944
#
# *** d_pred: 0.8944, abs_error: 0.0256
# search_pivot: 0.8944, search_scale (3*STD) = 0.1306
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8222 0.982 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0409, d_pred: 0.8766
#
# *** d_pred: 0.8766, abs_error: 0.0434
# search_pivot: 0.8766, search_scale (3*STD) = 0.1226
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8252 0.979 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0418, d_pred: 0.9176
#
# *** d_pred: 0.9176, abs_error: 0.0024
# search_pivot: 0.9176, search_scale (3*STD) = 0.1253
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8282 0.976 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0443, d_pred: 0.8849
#
# *** d_pred: 0.8849, abs_error: 0.0351
# search_pivot: 0.8849, search_scale (3*STD) = 0.1328
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8312 0.973 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0358, d_pred: 0.8736
#
# *** d_pred: 0.8736, abs_error: 0.0464
# search_pivot: 0.8736, search_scale (3*STD) = 0.1075
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8342 0.97  ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0366, d_pred: 0.9506
#
# *** d_pred: 0.9506, abs_error: 0.0306
# search_pivot: 0.9506, search_scale (3*STD) = 0.1099
#
# search_space: [0.8408 0.97  ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0351, d_pred: 0.9125
#
# *** d_pred: 0.9125, abs_error: 0.0075
# search_pivot: 0.9125, search_scale (3*STD) = 0.1053
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8438 0.967 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0357, d_pred: 0.9099
#
# *** d_pred: 0.9099, abs_error: 0.0101
# search_pivot: 0.9099, search_scale (3*STD) = 0.1071
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8468 0.964 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0334, d_pred: 0.9122
#
# *** d_pred: 0.9122, abs_error: 0.0078
# search_pivot: 0.9122, search_scale (3*STD) = 0.1003
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8498 0.961 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0322, d_pred: 0.9017
#
# *** d_pred: 0.9017, abs_error: 0.0183
# search_pivot: 0.9017, search_scale (3*STD) = 0.0966
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8528 0.958 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0289, d_pred: 0.8969
#
# *** d_pred: 0.8969, abs_error: 0.0231
# search_pivot: 0.8969, search_scale (3*STD) = 0.0868
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8558 0.955 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0276, d_pred: 0.8991
#
# *** d_pred: 0.8991, abs_error: 0.0209
# search_pivot: 0.8991, search_scale (3*STD) = 0.0827
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8588 0.952 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0286, d_pred: 0.8993
#
# *** d_pred: 0.8993, abs_error: 0.0207
# search_pivot: 0.8993, search_scale (3*STD) = 0.0857
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8618 0.949 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0245, d_pred: 0.8975
#
# *** d_pred: 0.8975, abs_error: 0.0225
# search_pivot: 0.8975, search_scale (3*STD) = 0.0736
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8648 0.946 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0253, d_pred: 0.9195
#
# *** d_pred: 0.9195, abs_error: 0.0005
# search_pivot: 0.9195, search_scale (3*STD) = 0.0760
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8678 0.943 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0227, d_pred: 0.9042
#
# *** d_pred: 0.9042, abs_error: 0.0158
# search_pivot: 0.9042, search_scale (3*STD) = 0.0682
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8708 0.94  ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0199, d_pred: 0.9024
#
# *** d_pred: 0.9024, abs_error: 0.0176
# search_pivot: 0.9024, search_scale (3*STD) = 0.0596
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8738 0.937 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0182, d_pred: 0.9072
#
# *** d_pred: 0.9072, abs_error: 0.0128
# search_pivot: 0.9072, search_scale (3*STD) = 0.0546
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8768 0.934 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0158, d_pred: 0.9045
#
# *** d_pred: 0.9045, abs_error: 0.0155
# search_pivot: 0.9045, search_scale (3*STD) = 0.0474
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8798 0.931 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0151, d_pred: 0.9211
#
# *** d_pred: 0.9211, abs_error: 0.0011
# search_pivot: 0.9211, search_scale (3*STD) = 0.0453
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8828 0.928 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0142, d_pred: 0.9050
#
# *** d_pred: 0.9050, abs_error: 0.0150
# search_pivot: 0.9050, search_scale (3*STD) = 0.0425
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8858 0.925 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0109, d_pred: 0.9016
#
# *** d_pred: 0.9016, abs_error: 0.0184
# search_pivot: 0.9016, search_scale (3*STD) = 0.0328
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8888 0.922 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0091, d_pred: 0.9038
#
# *** d_pred: 0.9038, abs_error: 0.0162
# search_pivot: 0.9038, search_scale (3*STD) = 0.0274
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8918 0.919 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0085, d_pred: 0.9075
#
# *** d_pred: 0.9075, abs_error: 0.0125
# search_pivot: 0.9075, search_scale (3*STD) = 0.0255
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8948 0.916 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0061, d_pred: 0.9074
#
# *** d_pred: 0.9074, abs_error: 0.0126
# search_pivot: 0.9074, search_scale (3*STD) = 0.0182
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8978 0.913 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0046, d_pred: 0.9064
#
# *** d_pred: 0.9064, abs_error: 0.0136
# search_pivot: 0.9064, search_scale (3*STD) = 0.0138
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.9008 0.91  ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0028, d_pred: 0.9058
#
# *** d_pred: 0.9058, abs_error: 0.0142
# search_pivot: 0.9058, search_scale (3*STD) = 0.0083
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.9038 0.907 ] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0010, d_pred: 0.9058
#
# *** d_pred: 0.9058, abs_error: 0.0142
# search_pivot: 0.9058, search_scale (3*STD) = 0.0029
# no change in search_space. narrowing by epsilon: 0.0030

# %%
# np.abs(res['pred_params'][-1] - res['test_params'][-1])
res['pred_params'][-1]
# Out:
# array([0.9054, 0.9054, 0.9055, 0.9054, 0.9054, 0.9054, 0.9058, 0.9054,
#        0.9054, 0.9054, 0.9054, 0.9055, 0.9054, 0.9058, 0.9057, 0.9045,
#        0.9046, 0.9054, 0.9054, 0.9054, 0.9056, 0.9054, 0.9054, 0.9058,
#        0.9056, 0.9054, 0.9057, 0.9055, 0.9058, 0.9056, 0.9054, 0.9059,
#        0.9054, 0.9058, 0.9054, 0.9055, 0.9055, 0.9054, 0.9057, 0.9057,
#        0.9055, 0.9054, 0.9056, 0.906 , 0.9059, 0.9054, 0.9054, 0.9058,
#        0.9054, 0.9054, 0.9051, 0.906 , 0.9054, 0.9057, 0.9054, 0.9059,
#        0.9049, 0.9054, 0.9054, 0.9054, 0.9054, 0.9055, 0.9054, 0.9054,
#        0.9054, 0.9055, 0.9054, 0.9055, 0.9054, 0.9054, 0.9054, 0.9054,
#        0.9047, 0.9053, 0.9058, 0.9054, 0.9054, 0.9049, 0.906 , 0.9054,
#        0.9054, 0.9054, 0.9059, 0.9054, 0.9054, 0.9052, 0.9053, 0.9045,
#        0.9054, 0.9054, 0.9054, 0.9054, 0.9054, 0.9054, 0.9056, 0.9055,
#        0.9055, 0.9055, 0.9054, 0.9054, 0.9054, 0.9057, 0.9054, 0.9054,
#        0.9054, 0.9048, 0.9056, 0.9056, 0.9054, 0.9054, 0.9054, 0.9054,
#        0.9054, 0.9058, 0.9055, 0.9054, 0.9054, 0.9054, 0.9054, 0.9054,
#        0.9054, 0.9054, 0.9054, 0.9053, 0.9047, 0.9051, 0.9055, 0.9054,
#        0.9054, 0.9054, 0.9054, 0.9054, 0.9054, 0.9054, 0.9054, 0.9054,
#        0.9051, 0.9059, 0.9054, 0.9054, 0.9054, 0.9054, 0.9055, 0.9054,
#        0.9054, 0.9055, 0.9053, 0.9054, 0.9047, 0.9058, 0.9056, 0.9054,
#        0.9058, 0.9054, 0.9057, 0.9056, 0.9054, 0.9055, 0.9058, 0.9054,
#        0.9052, 0.905 , 0.905 , 0.9058, 0.9054, 0.9054, 0.9054, 0.9058,
#        0.9054, 0.9056, 0.9054, 0.9058, 0.9056, 0.9054, 0.9054, 0.9054,
#        0.9057, 0.9054, 0.9054, 0.9056, 0.9054, 0.9054, 0.9051, 0.9056,
#        0.9058, 0.9058, 0.9052, 0.9056, 0.9054, 0.9054, 0.9054, 0.9055,
#        0.9054, 0.9054, 0.9056, 0.9054, 0.9054, 0.9055, 0.9054, 0.9059,
#        0.906 , 0.9054, 0.9054, 0.905 , 0.9054, 0.9054, 0.9057, 0.9054,
#        0.9058, 0.9054, 0.9054, 0.9054, 0.9053, 0.9054, 0.9057, 0.9054,
#        0.9058, 0.9055, 0.9054, 0.9055, 0.9054, 0.9054, 0.9056, 0.9054,
#        0.906 , 0.9054, 0.9054, 0.9047, 0.9058, 0.9058, 0.9056, 0.9041,
#        0.9047, 0.9054, 0.9058, 0.9054, 0.9058, 0.9044, 0.906 , 0.9055,
#        0.9056, 0.9054, 0.9054, 0.9058, 0.9054, 0.9054, 0.905 , 0.9054,
#        0.9054, 0.9057], dtype=float32)
