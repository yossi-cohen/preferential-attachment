# %% [markdown]
# # universal estimator-exp-1a (uniform sampling)
#
# Let $f(d)$ be a one dimensional function, that returns a samples drawn from a univariate distribution (e.g., log-normal).
#
# **Research question**: Let $e = (\vec{pred\_params} - \vec{test\_params})$.
# Does $STD(e)$ decreases when the parameter-search-space gets smaller?
#
# 1. Generate a sample (256 observations) using $f$ e.g: $sample = f(d=0.92, size=256)$
# 2. $estimator(f, sample)$ is a function which learns the parameter $d$ of $f$ from the sample.
#
# > - Init: search_space = [0, 1]
# >
# > - Iterate:
# >   1. Generate synthetic data-set ( train / test ) using $f(d)$ with two settings (exp-1a, exp-1b):
# >          d ~ uniform(search_space)
# >          d ~ norm(search_space)
# >   2. Fit a DNN model to the training set
# >          e = (pred_params - test_params)
# >          sigma = STD(e)
# >   3. Predict the parameter $d\_pred$ on the input sample using the DNN model
# >          d_pred = model.predict(sample)
# >   4. Narrow the search space:
# >          pivot = d_pred
# >          scale = 3 * std(e)
# >          search_space = [ pivot - scale, pivot + scale ]
# >          if next_search_space == search_space: narrow the search_space by epsilon = 0.003
# >          (here I'm interested merely on narrowing the search_space, not on "correct" focusing)
# >   5. Stop when either one of the following:
# >      - search-space-width < 1/128 * initial-search-space-width [0, 1]
# >      - std(e) <= 0.005
#
# > - Return:
# >   - d_pred_array: array of d_pred predicted at each iteration (3)
# >   - search_spaces: array of search-space at each iteration (4)
# >   - (pred-set, test-set) at each iteration
#
# 3. Plot a graph:
#
# >   - $x$: iteration #
# >   - $y1$: sigma_1 = STD(pred_params - test_params)
# >   - $y2$: abs(d_pred - d_true)
# >
# > Plot (shaded) intervals around sigma_1:
# >
# > - sigma_2:
# >          mu = mean(e)
# >          var_2 = 1/n * sum( ( (e - mu) ^ 2 - (sigma_1) ^ 2 ) ^ 2 )
# >          sigma_2 = sqrt(var_2)
# >
# > - 3 * sigma_1
#
# **Results**:
#
# The experiment was run on a true parameter: $d\_true =$ 0.92
# As can be shown by the plot:
# > 1. The error (sigma_1) keeps decreasing as we narrow the search-space.
# > 2. abs(d_pred - d_true) stabelizes (less flactuations) as we narrow the search-space.
# > 3. Observation: the model predictions (pred_params) in the last iteration are within the (narrowest) search space.
#
# ![image-3.png](attachment:image-3.png)

# %%
# import library
# %run lib.ipynb
np.set_printoptions(precision=4)

# %%
from scipy import stats
from scipy.stats import lognorm
from scipy.stats import yulesimon

# sample from lognormal
def sample_lognormal(config, size):
    return lognorm.rvs(s=config, size=size, random_state=RANDOM_STATE)

# sample from yulesimon
def sample_yulesimon(config, size):
    return yulesimon.rvs(alpha=config, size=size, random_state=RANDOM_STATE)

def next_config(search_space, loc=-1, scale=-1):

    """
    return a (uniform/normal) random parameter within search_space
    """
    low = search_space[0]
    high = search_space[1]
    if loc < 0:
        return np.random.uniform(low, high, size=1)[0]
    
    param = np.random.normal(loc=loc, scale=scale, size=1)[0]

    # adjust from left
    param_adjusted = max(search_space[0], param)
    param_adjusted = max(0.01, param)
    
    # adjust from right
    param_adjusted = min(param_adjusted, search_space[1])
    
    return param_adjusted

# %%
# def MAE(e, axis=-1):
#     """mean absolute error"""
#     return np.mean(np.abs(e), axis=axis)

NUM_BINS = 346

def predict_d(f, sample, d_true, search_space, num_trials=1, N=1000, search_pivot=-1, search_scale=-1):
    
    """
    Learn parameters of f, from sample.
    Arguments:
        - f: one dimensional function that gives the PMF of a univariate distribution.
        - sample: generated using f.
    """

    # number of observations in sample
    M = len(sample)
    N = N

    nbins = NUM_BINS
    
    # Generate a histogram for the input *sample*
    H_sample = np.histogram(sample, bins=nbins, range=(0,nbins), density=False)[0]
    H_sample = np.reshape(H_sample, (1, -1))
    
    # Iterate   
    d_pred_array = np.zeros(num_trials)
    for trial_idx in range(num_trials):

        # 1. Generate synthetic data-sets (train/test) using f (within search_space)
        # -----------------------------------------------------------------------------------------------
        print()
        print(f'search_space: {search_space} - trial ({trial_idx+1}/{num_trials})')
        print(f'generating data (M={M}, N={N})', end=', ')

        raw, H, params = generate_data(N=N, 
                                       M=M, 
                                       sample=f, 
                                       nextConfig=lambda: next_config(
                                           search_space, 
                                           loc=search_pivot, 
                                           scale=search_scale),
                                       nbins=nbins,
                                       density=False, 
                                       apply_log_scale=False)

        H_train, H_test, train_params, test_params = train_test_split(H, 
                                                                      params, 
                                                                      test_size=0.25, 
                                                                      random_state=RANDOM_STATE)

        # 2. Fit a DNN model to train-set and predict on test-set
        # -----------------------------------------------------------------------------------------------

        # train
        print(f'training ...', end=' ')
        dnn_model, history = dnn_fit(X_train=H_train, y_train=train_params)

        # predict test
        pred_params = dnn_model.predict(H_test).flatten()

        # error
        e = pred_params - test_params

        # 3. Predict the parameter (d_pred) on the input sample
        # -----------------------------------------------------------------------------------------------

        d_pred = dnn_model.predict(H_sample).flatten()[0]
        d_pred_array[trial_idx] = d_pred
        
        print(f'STD(test): {np.std(e):.4f}', end=', ')
        print(f'd_pred: {d_pred:.4f}', end='')
        if len(d_pred_array) > 1:
            print(f', avg(d_pred): {np.mean(d_pred_array[:trial_idx+1]):.4f}')
        else:
            print()

    return d_pred_array, test_params, pred_params

# %%
def estimator_exp_1(f, sample, d_true, initial_search_space):

    # experiment results
    res = {
        'search_space': [],
        'test_params': [],
        'pred_params': [],
        'd_true': d_true,
        'd_pred': [],
    }

    initial_search_space_width = initial_search_space[1] - initial_search_space[0]
    search_space = initial_search_space
    
    # Iterate
    it = 0
    search_pivot = -1
    search_scale = -1
    
    while True:
        
        it += 1
        
        num_trials = 1
        
        d_pred_array, test_params, pred_params = predict_d(f, 
                                                           sample, 
                                                           d_true, 
                                                           search_space, 
                                                           num_trials=num_trials, 
                                                           N=1000, 
#                                                            search_pivot=search_pivot, 
#                                                            search_scale=search_scale)
                                                           search_pivot=-1, 
                                                           search_scale=-1)
        
        d_pred = np.mean(d_pred_array)

        print()
        if len(d_pred_array) > 1:
            print(f'*** avg(d_pred): {d_pred:.4f}', end=', ')
        else:
            print(f'*** d_pred: {d_pred:.4f}', end=', ')
        print(f'abs_error: {abs(d_pred - d_true):.4f}')
        
        # save results
        res['search_space'].append(search_space)
        res['test_params'].append(test_params)
        res['pred_params'].append(pred_params)
        res['d_pred'].append(d_pred)
        
        # update the search_space
        # ------------------------

        search_pivot = d_pred
        search_STD = np.std(pred_params - test_params)

#         std_factor = 1
#         std_factor = 2
        std_factor = 3

        search_scale = std_factor * search_STD
        print(f'search_pivot: {search_pivot:.4f}, search_scale ({std_factor}*STD) = {search_scale:.4f}')
        
        next_search_space = np.array([ 
            max(search_space[0], search_pivot - search_scale), 
            min(search_space[1], search_pivot + search_scale)])
        
        # if no change in search_space, narrow by epsilon
        if np.array_equal(search_space, next_search_space):
            epsilon = 0.003
            print(f'no change in search_space. narrowing by epsilon: {epsilon:.4f}')
            search_space = np.array([search_space[0] + epsilon, search_space[1] - epsilon])
        else:
            search_space = next_search_space
        
        # stop condition: size of the search-space (high-low) is 1/128 of the original
        search_space_width = search_space[1] - search_space[0]
        search_space_shrink_factor = 1/128
        if search_space_width < search_space_shrink_factor * initial_search_space_width:
            break

        # stop condition (2): search_STD <=0.01
        if search_STD <= 0.001:
            break

    res['search_space'] = np.array(res['search_space'])
    res['test_params'] = np.array(res['test_params'])
    res['pred_params'] = np.array(res['pred_params'])
    res['d_pred'] = np.array(res['d_pred'])
    
    return res

# %% [markdown]
# ## Plot

# %%
def plot_search_space_size_vs_d_pred_error(res):

    search_space = res['search_space']
    search_space_width = search_space[:,1] - search_space[:,0]
    search_space_final = search_space[-1]
    
    d_true = res['d_true']
    d_pred = res['d_pred']
    d_pred_final = d_pred[-1] # d_pred of the last (narrowest) search_space
    d_pred_abs_error = np.abs(d_pred - d_true)

    pred_params = res['pred_params']
    test_params = res['test_params']

    # errors in each iteration
    e = pred_params - test_params
    
    # num-iterations
    n = e.shape[0]
    
    # avg error of each iteration
    mu = np.mean(e, axis=1).reshape((n,-1))
    
    # STD in each iteration
    sigma_1 = np.std(e, axis=1)

    # sigma_2
    mu = np.mean(e, axis=1).reshape(n, 1)
    var_2 = 1/n * np.sum(np.square(np.square(e - mu) - np.square(sigma_1).reshape(n,1)), axis=1)
    sigma_2 = np.sqrt(var_2)

    # iteration number
    x = np.array(range(n))
    
    # PLOT
    title = f'search space vs. prediction error \n\
    search_space_final: {search_space_final} \n\
    e = (pred_params - test_params) \n\
    d_true: {d_true}, d_pred_final: {d_pred_final:.4f}'
    
    fig, axes  = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
    
    for ax in axes:

        # zero reference line
        ax.plot(x, np.zeros(n), zorder=2, c='black', linewidth=0.5)

        ax.set_xlabel('iteration')
        
        if ax == axes[0]:
            ax.set_title(title)
            y1 = sigma_1
            y2 = d_pred_abs_error
            ax.set_ylabel('error')
        else:
            ax.set_title('log-scale')
            y1 = np.log10(y1)
            y2 = np.log10(y2)
            ax.set_ylabel('log10(error)')

        ax.scatter(x, y1, zorder=1, s=2, c='blue', label='sigma_1')
        ax.plot(x, y1, zorder=2, c='blue', alpha=0.2)
        
        # confidence_interval_1: sigma_1 +- 3*sigma_1
        ax.fill_between(range(len(x)), 
                         y1 - 3*sigma_1, y1 + 3*sigma_1, 
                         facecolor='green', alpha=0.2, label='3*sigma_1')

        # confidence_interval_2: sigma_1 +- sigma_2
        ax.fill_between(range(len(x)), 
                         y1 - sigma_2, y1 + sigma_2, 
                         facecolor='red', alpha=0.4, label='sigma_2')

        # y2 (d_pred)
        ax.scatter(x, y2, zorder=1, s=2, c='green', label='abs(d_pred - d_true)')
        ax.plot(x, y2, zorder=2, c='green', alpha=0.3)
    
        if ax == axes[0]:
            ax.legend(loc='upper right')
            
    plt.show()

# %% [markdown]
# ## Fit (lognormal)

# %%
for d_true in [0.92]:
    print()
    print(f'param true value: {d_true}')
    f = sample_lognormal
    sample = f(config=d_true, size=256)
    initial_search_space=np.array([0.0, 1.0])
    res = estimator_exp_1(f=f, sample=sample, d_true=d_true, initial_search_space=initial_search_space)
    plot_search_space_size_vs_d_pred_error(res)
# Out:
# param true value: 0.92
#
# search_space: [0. 1.] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0618, d_pred: 0.7791
#
# *** d_pred: 0.7791, abs_error: 0.1409
# search_pivot: 0.7791, search_scale (3*STD) = 0.1854
#
# search_space: [0.5937 0.9645] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0567, d_pred: 0.9055
#
# *** d_pred: 0.9055, abs_error: 0.0145
# search_pivot: 0.9055, search_scale (3*STD) = 0.1700
#
# search_space: [0.7355 0.9645] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0512, d_pred: 0.8762
#
# *** d_pred: 0.8762, abs_error: 0.0438
# search_pivot: 0.8762, search_scale (3*STD) = 0.1535
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7385 0.9615] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0491, d_pred: 0.8468
#
# *** d_pred: 0.8468, abs_error: 0.0732
# search_pivot: 0.8468, search_scale (3*STD) = 0.1472
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7415 0.9585] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0517, d_pred: 0.8125
#
# *** d_pred: 0.8125, abs_error: 0.1075
# search_pivot: 0.8125, search_scale (3*STD) = 0.1550
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7445 0.9555] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0468, d_pred: 0.8411
#
# *** d_pred: 0.8411, abs_error: 0.0789
# search_pivot: 0.8411, search_scale (3*STD) = 0.1403
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7475 0.9525] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0498, d_pred: 0.8484
#
# *** d_pred: 0.8484, abs_error: 0.0716
# search_pivot: 0.8484, search_scale (3*STD) = 0.1493
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7505 0.9495] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0501, d_pred: 0.8318
#
# *** d_pred: 0.8318, abs_error: 0.0882
# search_pivot: 0.8318, search_scale (3*STD) = 0.1502
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7535 0.9465] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0520, d_pred: 0.8008
#
# *** d_pred: 0.8008, abs_error: 0.1192
# search_pivot: 0.8008, search_scale (3*STD) = 0.1561
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7565 0.9435] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0442, d_pred: 0.7859
#
# *** d_pred: 0.7859, abs_error: 0.1341
# search_pivot: 0.7859, search_scale (3*STD) = 0.1326
#
# search_space: [0.7565 0.9185] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0401, d_pred: 0.8540
#
# *** d_pred: 0.8540, abs_error: 0.0660
# search_pivot: 0.8540, search_scale (3*STD) = 0.1202
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7595 0.9155] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0408, d_pred: 0.8019
#
# *** d_pred: 0.8019, abs_error: 0.1181
# search_pivot: 0.8019, search_scale (3*STD) = 0.1223
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7625 0.9125] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0383, d_pred: 0.8575
#
# *** d_pred: 0.8575, abs_error: 0.0625
# search_pivot: 0.8575, search_scale (3*STD) = 0.1150
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7655 0.9095] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0396, d_pred: 0.8358
#
# *** d_pred: 0.8358, abs_error: 0.0842
# search_pivot: 0.8358, search_scale (3*STD) = 0.1188
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7685 0.9065] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0398, d_pred: 0.8462
#
# *** d_pred: 0.8462, abs_error: 0.0738
# search_pivot: 0.8462, search_scale (3*STD) = 0.1194
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7715 0.9035] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0362, d_pred: 0.8296
#
# *** d_pred: 0.8296, abs_error: 0.0904
# search_pivot: 0.8296, search_scale (3*STD) = 0.1087
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7745 0.9005] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0349, d_pred: 0.7891
#
# *** d_pred: 0.7891, abs_error: 0.1309
# search_pivot: 0.7891, search_scale (3*STD) = 0.1046
#
# search_space: [0.7745 0.8936] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0336, d_pred: 0.8780
#
# *** d_pred: 0.8780, abs_error: 0.0420
# search_pivot: 0.8780, search_scale (3*STD) = 0.1007
#
# search_space: [0.7774 0.8936] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0315, d_pred: 0.8656
#
# *** d_pred: 0.8656, abs_error: 0.0544
# search_pivot: 0.8656, search_scale (3*STD) = 0.0946
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7804 0.8906] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0291, d_pred: 0.8532
#
# *** d_pred: 0.8532, abs_error: 0.0668
# search_pivot: 0.8532, search_scale (3*STD) = 0.0874
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7834 0.8876] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0274, d_pred: 0.8383
#
# *** d_pred: 0.8383, abs_error: 0.0817
# search_pivot: 0.8383, search_scale (3*STD) = 0.0822
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7864 0.8846] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0311, d_pred: 0.8484
#
# *** d_pred: 0.8484, abs_error: 0.0716
# search_pivot: 0.8484, search_scale (3*STD) = 0.0933
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7894 0.8816] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0265, d_pred: 0.8466
#
# *** d_pred: 0.8466, abs_error: 0.0734
# search_pivot: 0.8466, search_scale (3*STD) = 0.0794
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7924 0.8786] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0266, d_pred: 0.8169
#
# *** d_pred: 0.8169, abs_error: 0.1031
# search_pivot: 0.8169, search_scale (3*STD) = 0.0799
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7954 0.8756] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0251, d_pred: 0.8425
#
# *** d_pred: 0.8425, abs_error: 0.0775
# search_pivot: 0.8425, search_scale (3*STD) = 0.0754
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.7984 0.8726] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0224, d_pred: 0.8320
#
# *** d_pred: 0.8320, abs_error: 0.0880
# search_pivot: 0.8320, search_scale (3*STD) = 0.0673
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8014 0.8696] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0198, d_pred: 0.8284
#
# *** d_pred: 0.8284, abs_error: 0.0916
# search_pivot: 0.8284, search_scale (3*STD) = 0.0593
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8044 0.8666] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0177, d_pred: 0.8410
#
# *** d_pred: 0.8410, abs_error: 0.0790
# search_pivot: 0.8410, search_scale (3*STD) = 0.0531
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8074 0.8636] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0163, d_pred: 0.8344
#
# *** d_pred: 0.8344, abs_error: 0.0856
# search_pivot: 0.8344, search_scale (3*STD) = 0.0490
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8104 0.8606] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0145, d_pred: 0.8333
#
# *** d_pred: 0.8333, abs_error: 0.0867
# search_pivot: 0.8333, search_scale (3*STD) = 0.0435
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8134 0.8576] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0130, d_pred: 0.8344
#
# *** d_pred: 0.8344, abs_error: 0.0856
# search_pivot: 0.8344, search_scale (3*STD) = 0.0389
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8164 0.8546] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0108, d_pred: 0.8391
#
# *** d_pred: 0.8391, abs_error: 0.0809
# search_pivot: 0.8391, search_scale (3*STD) = 0.0324
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8194 0.8516] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0100, d_pred: 0.8352
#
# *** d_pred: 0.8352, abs_error: 0.0848
# search_pivot: 0.8352, search_scale (3*STD) = 0.0299
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8224 0.8486] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0081, d_pred: 0.8362
#
# *** d_pred: 0.8362, abs_error: 0.0838
# search_pivot: 0.8362, search_scale (3*STD) = 0.0244
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8254 0.8456] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0059, d_pred: 0.8371
#
# *** d_pred: 0.8371, abs_error: 0.0829
# search_pivot: 0.8371, search_scale (3*STD) = 0.0178
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8284 0.8426] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0042, d_pred: 0.8345
#
# *** d_pred: 0.8345, abs_error: 0.0855
# search_pivot: 0.8345, search_scale (3*STD) = 0.0126
# no change in search_space. narrowing by epsilon: 0.0030
#
# search_space: [0.8314 0.8396] - trial (1/1)
# generating data (M=256, N=1000), training ... STD(test): 0.0025, d_pred: 0.8356
#
# *** d_pred: 0.8356, abs_error: 0.0844
# search_pivot: 0.8356, search_scale (3*STD) = 0.0076
# no change in search_space. narrowing by epsilon: 0.0030

# %%
# np.abs(res['pred_params'][-1] - res['test_params'][-1])
res['pred_params'][-1]
# Out:
# array([0.8357, 0.836 , 0.8354, 0.8353, 0.836 , 0.836 , 0.8359, 0.836 ,
#        0.8352, 0.8359, 0.836 , 0.835 , 0.8359, 0.8334, 0.8355, 0.8348,
#        0.836 , 0.8352, 0.8358, 0.8342, 0.8359, 0.836 , 0.8355, 0.8353,
#        0.8359, 0.836 , 0.8362, 0.834 , 0.836 , 0.8351, 0.8359, 0.8356,
#        0.836 , 0.8343, 0.8359, 0.8359, 0.835 , 0.8363, 0.8365, 0.8353,
#        0.8356, 0.8353, 0.8359, 0.8359, 0.8352, 0.8355, 0.8345, 0.8359,
#        0.836 , 0.8361, 0.836 , 0.836 , 0.8359, 0.8361, 0.8359, 0.836 ,
#        0.8362, 0.836 , 0.8364, 0.8353, 0.836 , 0.8354, 0.8359, 0.8354,
#        0.8338, 0.8354, 0.8362, 0.8356, 0.8367, 0.8361, 0.8359, 0.8364,
#        0.8337, 0.8354, 0.8361, 0.8346, 0.8359, 0.8363, 0.8359, 0.8356,
#        0.8357, 0.8366, 0.835 , 0.8355, 0.8347, 0.8361, 0.8359, 0.836 ,
#        0.8355, 0.8345, 0.836 , 0.8339, 0.8357, 0.8359, 0.8353, 0.8362,
#        0.8354, 0.8359, 0.836 , 0.8357, 0.8342, 0.832 , 0.8359, 0.8346,
#        0.835 , 0.8355, 0.8359, 0.836 , 0.8352, 0.836 , 0.836 , 0.8351,
#        0.8352, 0.8359, 0.8344, 0.8359, 0.8362, 0.8362, 0.8362, 0.8357,
#        0.836 , 0.8353, 0.8359, 0.8353, 0.8363, 0.8364, 0.8361, 0.836 ,
#        0.8357, 0.8346, 0.8357, 0.8339, 0.8358, 0.8359, 0.836 , 0.8352,
#        0.8359, 0.8359, 0.8359, 0.8353, 0.8356, 0.836 , 0.8349, 0.836 ,
#        0.8338, 0.8359, 0.8349, 0.836 , 0.8344, 0.8359, 0.836 , 0.8357,
#        0.8351, 0.8359, 0.8351, 0.8359, 0.8355, 0.8357, 0.8351, 0.8359,
#        0.8353, 0.836 , 0.8359, 0.8357, 0.8351, 0.836 , 0.8324, 0.8358,
#        0.836 , 0.836 , 0.835 , 0.836 , 0.8356, 0.8358, 0.836 , 0.8362,
#        0.8357, 0.8354, 0.836 , 0.836 , 0.8353, 0.8348, 0.8347, 0.8352,
#        0.8354, 0.8347, 0.8358, 0.8348, 0.8335, 0.8362, 0.8351, 0.8358,
#        0.8348, 0.836 , 0.8359, 0.8359, 0.8354, 0.8347, 0.8359, 0.8359,
#        0.8351, 0.835 , 0.8332, 0.8359, 0.8363, 0.835 , 0.8352, 0.8359,
#        0.8359, 0.8363, 0.8359, 0.8355, 0.8365, 0.8357, 0.8363, 0.8359,
#        0.8361, 0.8359, 0.8359, 0.8354, 0.836 , 0.8347, 0.8363, 0.836 ,
#        0.836 , 0.8359, 0.8347, 0.8353, 0.8359, 0.8359, 0.8348, 0.8342,
#        0.834 , 0.8359, 0.8359, 0.8357, 0.8356, 0.8346, 0.8359, 0.836 ,
#        0.8358, 0.8352, 0.8352, 0.8348, 0.836 , 0.836 , 0.8358, 0.835 ,
#        0.8359, 0.8355], dtype=float32)
